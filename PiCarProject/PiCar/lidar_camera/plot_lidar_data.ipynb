# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.load("lidar_data.npy")
arr
# Out:
# array([[ 15.      , 173.71875 , 464.5     ],
#        [ 15.      , 175.265625, 461.5     ],
#        [ 15.      , 176.359375, 460.      ],
#        [ 15.      , 177.859375, 459.25    ],
#        [ 15.      , 179.203125, 459.75    ],
#        [ 15.      , 180.359375, 459.5     ],
#        [ 15.      , 181.515625, 460.      ],
#        [ 15.      , 183.140625, 460.75    ],
#        [ 15.      , 184.296875, 460.      ],
#        [ 15.      , 185.46875 , 460.      ],
#        [ 15.      , 186.875   , 463.5     ],
#        [ 15.      , 204.71875 , 986.      ],
#        [ 15.      , 173.625   , 464.75    ],
#        [ 15.      , 175.109375, 461.25    ],
#        [ 15.      , 176.46875 , 459.75    ],
#        [ 15.      , 177.796875, 458.75    ],
#        [ 15.      , 178.90625 , 460.      ],
#        [ 15.      , 180.15625 , 459.25    ],
#        [ 15.      , 181.5625  , 460.5     ],
#        [ 15.      , 183.      , 461.      ],
#        [ 15.      , 184.390625, 460.      ],
# ...

# %%
angle = arr[:, 1]
dist = arr[:, 2]

x = dist*np.sin(angle*np.pi/180)
y = dist*np.cos(angle*np.pi/180)

# %%
np.array(list(zip(x, y)))
# Out:
# array([[ 5.08204955e+01, -4.61711519e+02],
#        [ 3.80905640e+01, -4.59925384e+02],
#        [ 2.92091465e+01, -4.59071700e+02],
#        [ 1.71540269e+01, -4.58929517e+02],
#        [ 6.39403937e+00, -4.59705535e+02],
#        [-2.88209238e+00, -4.59490961e+02],
#        [-1.21667983e+01, -4.59839069e+02],
#        [-2.52430189e+01, -4.60057988e+02],
#        [-3.44651958e+01, -4.58707042e+02],
#        [-4.38393036e+01, -4.57906230e+02],
#        [-5.54826442e+01, -4.60167281e+02],
#        [-4.12310059e+02, -8.95654183e+02],
#        [ 5.16036597e+01, -4.61876201e+02],
#        [ 3.93233592e+01, -4.59570708e+02],
#        [ 2.83173489e+01, -4.58877097e+02],
#        [ 1.76354099e+01, -4.58410902e+02],
#        [ 8.78065448e+00, -4.59916188e+02],
#        [-1.25240854e+00, -4.59248292e+02],
#        [-1.25566329e+01, -4.60328775e+02],
#        [-2.41268758e+01, -4.60368216e+02],
#        [-3.52157070e+01, -4.58650034e+02],
#        [-4.59367131e+01, -4.57449321e+02],
# ...

# %%
plt.scatter(x, y)
