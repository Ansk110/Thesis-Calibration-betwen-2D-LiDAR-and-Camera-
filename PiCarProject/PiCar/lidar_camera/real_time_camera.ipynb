# %%
from picamera.array import PiRGBArray
from picamera import PiCamera
import time
import cv2
import os

# %%
import matplotlib.pyplot as plt

# %%
W, H = (864, 544)

camera = PiCamera()
camera.resolution = (W, H)
camera.framerate = 32

# %%
rawCapture = PiRGBArray(camera, size=(W, H))

# %%
image_index = 1

cv2.namedWindow("Image")
for frame in camera.capture_continuous(rawCapture, format="bgr", use_video_port=True):    
    image = frame.array
    plt.imshow(image)
    rawCapture.truncate(0)

    image_index += 1
    print(image_index, end="\r")
# Out:
# 70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/picamera/camera.py:1702, in PiCamera.capture_continuous(self, output, format, use_video_port, resize, splitter_port, burst, bayer, **options)
#    1701 encoder.start(output)
# -> 1702 if not encoder.wait(self.CAPTURE_TIMEOUT):
#    1703     raise PiCameraRuntimeError(
#    1704         'Timed out waiting for capture to end')
#
# File /usr/lib/python3/dist-packages/picamera/encoders.py:393, in PiEncoder.wait(self, timeout)
#     383 """
#     384 Waits for the encoder to finish (successfully or otherwise).
#     385
#    (...)
#     391 the method returns ``True``. Otherwise, it returns ``False``.
#     392 """
# --> 393 result = self.event.wait(timeout)
#     394 if result:
#
# File /usr/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File /usr/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     315 if timeout > 0:
# --> 316     gotit = waiter.acquire(True, timeout)
#     317 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PiCameraValueError                        Traceback (most recent call last)
# Cell In[8], line 5
#       2 image_index = 1
#       4 cv2.namedWindow("Image")
# ----> 5 for frame in camera.capture_continuous(rawCapture, format="bgr", use_video_port=True):
#       6     image = frame.array
#       7     plt.imshow(image)
#
# File /usr/lib/python3/dist-packages/picamera/camera.py:1710, in PiCamera.capture_continuous(self, output, format, use_video_port, resize, splitter_port, burst, bayer, **options)
#    1708             camera_port.params[mmal.MMAL_PARAMETER_CAMERA_BURST_CAPTURE] = False
#    1709 finally:
# -> 1710     encoder.close()
#    1711     with self._encoders_lock:
#    1712         if use_video_port:
#
# File /usr/lib/python3/dist-packages/picamera/encoders.py:431, in PiEncoder.close(self)
#     421 def close(self):
#     422     """
#     423     Finalizes the encoder and deallocates all structures.
#     424
#    (...)
#     429     attributes.
#     430     """
# --> 431     self.stop()
#     432     if self.encoder:
#     433         self.encoder.disconnect()
#
# File /usr/lib/python3/dist-packages/picamera/encoders.py:419, in PiEncoder.stop(self)
#     417     self.output_port.disable()
#     418 self.event.set()
# --> 419 self._close_output()
#
# File /usr/lib/python3/dist-packages/picamera/encoders.py:349, in PiEncoder._close_output(self, key)
#     347     pass
#     348 else:
# --> 349     mo.close_stream(output, opened)
#
# File /usr/lib/python3/dist-packages/picamera/mmalobj.py:371, in close_stream(stream, opened)
#     369 else:
#     370     try:
# --> 371         stream.flush()
#     372     except AttributeError:
#     373         pass
#
# File /usr/lib/python3/dist-packages/picamera/array.py:238, in PiRGBArray.flush(self)
#     236 def flush(self):
#     237     super(PiRGBArray, self).flush()
# --> 238     self.array = bytes_to_rgb(self.getvalue(), self.size or self.camera.resolution)
#
# File /usr/lib/python3/dist-packages/picamera/array.py:126, in bytes_to_rgb(data, resolution)
#     124     fwidth, fheight = raw_resolution(resolution, splitter=True)
#     125     if len(data) != (fwidth * fheight * 3):
# --> 126         raise PiCameraValueError(
#     127             'Incorrect buffer length for resolution %dx%d' % (width, height))
#     128 # Crop to the actual resolution
#     129 return np.frombuffer(data, dtype=np.uint8).\
#     130         reshape((fheight, fwidth, 3))[:height, :width, :]
#
# PiCameraValueError: Incorrect buffer length for resolution 864x544

# %%
camera.close()
cv2.destroyAllWindows()
